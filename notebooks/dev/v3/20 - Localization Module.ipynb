# %% [markdown]
# # Localization Module

# %%
push!(LOAD_PATH, "../src");
push!(LOAD_PATH, ENV["probcomp"]*"/Gen-Distribution-Zoo/src");

# %%
#nbx --fname="src/Localization.jl" --jl_module=Localization

using BenchmarkTools;
using Colors, Plots, Images;
col = palette(:default);
(cgrad::PlotUtils.ContinuousColorGradient)(xs::Vector{Vector{Float64}}) = [cgrad[x] for x in xs];
(cgrad::PlotUtils.ContinuousColorGradient)(m::Matrix{Float64}) = reshape(cgrad[m[:]], size(m));

using Fmt: @f_str, format # Python-style f-strings
using StatsBase: mean
using Random: shuffle, randperm

using Gen
using GenDistributionZoo: ProductDistribution, diagnormal
using MyUtils
using CUDA
using MyCudaUtils
using Geometry: Segment, bounding_box, segments

include("../src/pose.jl");
include("../src/cuda_raycaster_line_map_b.jl");
include("../v2/src/sensor_distribution.jl");

# %%
include("src/data_helper.jl");

fname = "../data/task_inputs/test_env_1.json"
_segs, _boxes, _paths = load_env(fname)
_bb = bounding_box(_segs);
_ps, _us = unpack_path(_paths[1]);

# %%
function lims(_segs, d=1.0)
    _bb = bounding_box(_segs);
    return Dict(
        :xlims => (_bb[1][1]-d, _bb[2][1]+d), 
        :ylims => (_bb[1][2]-d, _bb[2][2]+d)
    )
end
# Out:
# lims (generic function with 2 methods)

# %%
plot(size=(200,200), aspect_ratio=:equal; lims(_segs)...)
plot!(_segs, c=:black)

# %%
mvuniform = ProductDistribution(uniform);

# %%
#nbx
@gen function sensor_model(p, segs, as, fov, w, sig, outlier, zmax, scale_noise=false, noise_anchor=1.0)
    
    segs_ = DeviceArray(stack(Vector.(segs)))
    p_    = DeviceArray(Vector(p))
    ps_   = reshape(p_, 1, 3)

    zs_ = cast(ps_, segs_; fov=fov, num_a=length(as), zmax=zmax)
    as_ = DeviceArray(as)

    ỹ_, d̃_ = get_1d_mixture_components(zs_, as_, w; 
                wrap=false, fill=true, fill_val_z=zmax, fill_val_a=0.0);

    ỹ_ = ỹ_[1,:,:]
    d̃_ = d̃_[1,:,:]

    z ~ depthdist_2dp3(ỹ_, d̃_, sig, outlier, zmax, scale_noise, noise_anchor)

    return z
end;

# %%
p = _ps[1]

_fov   = 2π
_num_a = 300
_as    = create_angles(_fov, _num_a)

w       = 20
sig     = 0.1
outlier = 0.1
zmax    = 80.0

scale_noise  = true
noise_anchor = 3.0

segs = _segs
as = _as

segs_ = DeviceArray(stack(Vector.(segs)))
p_    = DeviceArray(Vector(p))
ps_   = reshape(p_, 1, 3)

zs_ = cast(ps_, segs_; fov=fov, num_a=length(as), zmax=zmax)
as_ = DeviceArray(as)


ỹ_, d̃_ = get_1d_mixture_components(zs_, as_, w; 
            wrap=false, fill=false, fill_val_z=zmax, fill_val_a=0.0);

any(ỹ_  .< 0),
any(zs_ .< 0)
# Out:
# (false, false)

# %%
p = _ps[1]

_fov   = 2π
_num_a = 100
_as    = create_angles(_fov, _num_a)

w       = 20
sig     = 0.1
outlier = 0.1
zmax    = 80.0

scale_noise  = true
noise_anchor = 3.0


z = sensor_model(p, _segs, _as, _fov, w, sig, outlier, zmax, scale_noise, noise_anchor)
y = polar_inv(z, _as)

# ----------------------
plot(size=(400,400), aspect_ratio=:equal; lims(_segs, 2)...)
plot!(_segs, c=:black)
plot!(p, c=:red, linewidth=2)
scatter!(y .* p, c=col[1], label="Obs")
# Out:
# 80.0
# DomainError with -2.666666666666667:
#
# Normal: the condition σ >= zero(σ) is not satisfied.
#
#
#
# Stacktrace:
#
#   [1] #363
#
#     @ ~/.julia/packages/Distributions/YQQXX/src/univariate/continuous/normal.jl:37 [inlined]
#
#   [2] check_args
#
#     @ ~/.julia/packages/Distributions/YQQXX/src/utils.jl:89 [inlined]
#
#   [3] #Normal#362
#
#     @ ~/.julia/packages/Distributions/YQQXX/src/univariate/continuous/normal.jl:37 [inlined]
#
#   [4] Normal
#
#     @ ~/.julia/packages/Distributions/YQQXX/src/univariate/continuous/normal.jl:36 [inlined]
#
#   [5] TruncatedNormal(mu::Float64, sigma::Float64, a::Float64, b::Float64)
#
#     @ Distributions ./deprecated.jl:72
#
#   [6] random(::DepthDistribution2DP3, ỹ::CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, d̃::CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, sig::Float64, outlier::Float64, zmax::Float64, scale_noise::Bool, noise_anchor::Float64)
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v2/src/sensor_distribution.jl:735
#
#   [7] traceat
#
#     @ ~/.julia/packages/Gen/Dne3u/src/dynamic/dynamic.jl:87 [inlined]
#
#   [8] var"##sensor_model#1221"(state#314::Gen.GFUntracedState, p::Pose, segs::Vector{Segment}, as::Vector{Float64}, fov::Float64, w::Int64, sig::Float64, outlier::Float64, zmax::Float64, scale_noise::Bool, noise_anchor::Float64)
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v3/20 - Localization Module.ipynb:18
#
#   [9] (::DynamicDSLFunction{Any})(::Pose, ::Vararg{Any})
#
#     @ Gen ~/.julia/packages/Gen/Dne3u/src/dynamic/dynamic.jl:54
#
#  [10] top-level scope
#
#     @ ~/workspace/probabilistic-slam-in-gen/notebooks/v3/20 - Localization Module.ipynb:16

# %%
tr = simulate(sensor_model, (p, _segs, _as, _fov, w, sig, outlier, zmax, scale_noise, noise_anchor))
# Out:
# GPU compilation of kernel #broadcast_kernel#28(CUDA.CuKernelContext, CuDeviceArray{Float64, 3, 1}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(/), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}}}, Int64) failed
#
# KernelError: passing and using non-bitstype argument
#
#
#
# Argument 4 to your kernel function is of type Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(/), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}}}, which is not isbits:
#
#   .args is of type Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}} which is not isbits.
#
#     .1 is of type Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}} which is not isbits.
#
#       .args is of type Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}} which is not isbits.
#
#         .2 is of type Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}} which is not isbits.
#
#           .args is of type Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}} which is not isbits.
#
#             .1 is of type Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}} which is not isbits.
#
#               .x is of type Array{Float64, 3} which is not isbits.
#
#
#
#
#
#
#
# Stacktrace:
#
#   [1] check_invocation(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/S3TWf/src/validation.jl:88
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/S3TWf/src/driver.jl:154 [inlined]
#
#   [3] macro expansion
#
#     @ ~/.julia/packages/TimerOutputs/LHjFw/src/TimerOutput.jl:253 [inlined]
#
#   [4] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/S3TWf/src/driver.jl:152 [inlined]
#
#   [5] emit_julia(job::GPUCompiler.CompilerJob; validate::Bool)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/S3TWf/src/utils.jl:83
#
#   [6] emit_julia
#
#     @ ~/.julia/packages/GPUCompiler/S3TWf/src/utils.jl:77 [inlined]
#
#   [7] cufunction_compile(job::GPUCompiler.CompilerJob, ctx::LLVM.Context)
#
#     @ CUDA ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:359
#
#   [8] #221
#
#     @ ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:354 [inlined]
#
#   [9] JuliaContext(f::CUDA.var"#221#222"{GPUCompiler.CompilerJob{GPUCompiler.PTXCompilerTarget, CUDA.CUDACompilerParams, GPUCompiler.FunctionSpec{GPUArrays.var"#broadcast_kernel#28", Tuple{CUDA.CuKernelContext, CuDeviceArray{Float64, 3, 1}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(/), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}}}, Int64}}}})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/S3TWf/src/driver.jl:76
#
#  [10] cufunction_compile(job::GPUCompiler.CompilerJob)
#
#     @ CUDA ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:353
#
#  [11] cached_compilation(cache::Dict{UInt64, Any}, job::GPUCompiler.CompilerJob, compiler::typeof(CUDA.cufunction_compile), linker::typeof(CUDA.cufunction_link))
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/S3TWf/src/cache.jl:90
#
#  [12] cufunction(f::GPUArrays.var"#broadcast_kernel#28", tt::Type{Tuple{CUDA.CuKernelContext, CuDeviceArray{Float64, 3, 1}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(/), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}}}, Int64}}; name::Nothing, always_inline::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ CUDA ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:306
#
#  [13] cufunction(f::GPUArrays.var"#broadcast_kernel#28", tt::Type{Tuple{CUDA.CuKernelContext, CuDeviceArray{Float64, 3, 1}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(/), Tuple{Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(-), Tuple{Base.Broadcast.Extruded{Array{Float64, 3}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}}}, CUDA.CuRefValue{Val{2}}}}, Base.Broadcast.Broadcasted{CUDA.CuArrayStyle{3}, Nothing, typeof(Base.literal_pow), Tuple{CUDA.CuRefValue{typeof(^)}, Base.Broadcast.Extruded{CuDeviceArray{Float64, 3, 1}, Tuple{Bool, Bool, Bool}, Tuple{Int64, Int64, Int64}}, CUDA.CuRefValue{Val{2}}}}}}, Int64}})
#
#     @ CUDA ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:299
#
#  [14] macro expansion
#
#     @ ~/.julia/packages/CUDA/ZdCxS/src/compiler/execution.jl:102 [inlined]
#
#  [15] #launch_heuristic#245
#
#     @ ~/.julia/packages/CUDA/ZdCxS/src/gpuarrays.jl:17 [inlined]
#
#  [16] _copyto!
#
#     @ ~/.julia/packages/GPUArrays/TnEpb/src/host/broadcast.jl:65 [inlined]
#
#  [17] copyto!
#
#     @ ~/.julia/packages/GPUArrays/TnEpb/src/host/broadcast.jl:46 [inlined]
#
#  [18] copy
#
#     @ ~/.julia/packages/GPUArrays/TnEpb/src/host/broadcast.jl:37 [inlined]
#
#  [19] materialize
#
#     @ ./broadcast.jl:860 [inlined]
#
#  [20] gaussian_logpdf(x::Array{Float64, 3}, mu::CuArray{Float64, 3, CUDA.Mem.DeviceBuffer}, sig::CuArray{Float64, 3, CUDA.Mem.DeviceBuffer})
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v2/src/sensor_distribution.jl:30
#
#  [21] depthdist_logpdf(z::Vector{Float64}, ỹ::CuArray{Float64, 3, CUDA.Mem.DeviceBuffer}, d̃::CuArray{Float64, 3, CUDA.Mem.DeviceBuffer}, sig::Float64, outlier::Float64, zmax::Float64, scale_noise::Bool, noise_anchor::Float64; return_pointwise::Bool, return_outliermap::Bool)
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v2/src/sensor_distribution.jl:634
#
#  [22] logpdf(::DepthDistribution2DP3, z::Vector{Float64}, ỹ::CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, d̃::CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, sig::Float64, outlier::Float64, zmax::Float64, scale_noise::Bool, noise_anchor::Float64)
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v2/src/sensor_distribution.jl:697
#
#  [23] traceat(state::Gen.GFSimulateState, dist::DepthDistribution2DP3, args::Tuple{CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, CuArray{Float64, 2, CUDA.Mem.DeviceBuffer}, Float64, Float64, Float64, Bool, Float64}, key::Symbol)
#
#     @ Gen ~/.julia/packages/Gen/Dne3u/src/dynamic/simulate.jl:22
#
#  [24] var"##sensor_model#896"(state#314::Gen.GFSimulateState, p::Pose, segs::Vector{Segment}, as::Vector{Float64}, fov::Float64, w::Int64, sig::Float64, outlier::Float64, zmax::Float64, scale_noise::Bool, noise_anchor::Float64)
#
#     @ Main ~/workspace/probabilistic-slam-in-gen/notebooks/v3/20 - Localization Module.ipynb:17
#
#  [25] exec(gen_fn::DynamicDSLFunction{Any}, state::Gen.GFSimulateState, args::Tuple{Pose, Vector{Segment}, Vector{Float64}, Float64, Int64, Float64, Float64, Float64, Bool, Float64})
#
#     @ Gen ~/.julia/packages/Gen/Dne3u/src/dynamic/dynamic.jl:58
#
#  [26] simulate(gen_fn::DynamicDSLFunction{Any}, args::Tuple{Pose, Vector{Segment}, Vector{Float64}, Float64, Int64, Float64, Float64, Float64, Bool, Float64})
#
#     @ Gen ~/.julia/packages/Gen/Dne3u/src/dynamic/simulate.jl:61
#
#  [27] top-level scope
#
#     @ ~/workspace/probabilistic-slam-in-gen/notebooks/v3/20 - Localization Module.ipynb:1
