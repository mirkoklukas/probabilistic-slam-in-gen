# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("nbAgg")
# %matplotlib notebook

import sys
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.plot(np.random.rand(10))

xs = []
def onclick(event):
    xs.append([event.xdata, event.ydata])
    tx = 'button=%d, x=%d, y=%d, xdata=%f, ydata=%f' % (event.button, event.x, event.y, event.xdata, event.ydata)
    print("asf")

cid = fig.canvas.mpl_connect('button_press_event', onclick);

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xs
# Out:
# [[4.373692666330644, 0.6401323240776625],
#  [2.597281376008064, 0.679446374912286],
#  [3.196071698588709, 0.6868177594437779],
#  [3.395668472782257, 0.6941891439752698],
#  [3.6751039566532246, 0.7064747848610896],
#  [3.5154265372983864, 0.7801886301760086],
#  [3.6152249243951604, 0.8096741683019762],
#  [3.794862021169354, 0.7654458611130248],
#  [3.794862021169354, 0.6081896577745309],
#  [4.313813634072579, 0.5074474025108083],
#  [4.293853956653225, 0.45093345443603705],
#  [4.034378150201611, 0.5664184787627435],
#  [3.834781376008064, 0.6155610423060228],
#  [3.65514427923387, 0.6425894522548264],
#  [3.635184601814515, 0.6450465804319905],
#  [3.535386214717741, 0.6376751959004986],
#  [3.5154265372983864, 0.5909897605343832],
#  [None, None],
#  [4.333773311491935, 0.7236746821012374],
#  [4.253934601814516, 0.6991034003295977],
#  [3.2759104082661286, 0.6524179649634824],
#  [3.495466859879031, 0.5909897605343832],
#  [3.934579763104838, 0.5639613505855795],
#  [4.0942571824596765, 0.5590470942312517],
#  [4.074297505040322, 0.5565899660540876],
#  [4.074297505040322, 0.5541328378769237],
#  [4.074297505040322, 0.5565899660540876],
#  [4.074297505040322, 0.5565899660540876],
#  [4.054337827620966, 0.5565899660540876],
#  [5.052321698588708, 0.3477340709951505],
#  [5.172079763104838, 0.3280770455778388],
#  [None, None],
#  [None, None],
#  [None, None],
#  [None, None],
#  [None, None],
#  [None, None]]
